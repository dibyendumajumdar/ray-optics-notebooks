# %%
# %matplotlib inline
isdark = False
from rayoptics.environment import *
from rayoptics.elem.elements import Element
from rayoptics.raytr.trace import apply_paraxial_vignetting

# US2019/0265441 Example 2 (Canon RF 50mm F1.2 L USM)
# Obtained via https://www.photonstophotos.net/GeneralTopics/Lenses/OpticalBench/OpticalBenchHub.htm

opm = OpticalModel()
sm  = opm.seq_model
osp = opm.optical_spec
pm = opm.parax_model
osp.pupil = PupilSpec(osp, key=['image', 'f/#'], value=1.25)
osp.field_of_view = FieldSpec(osp, key=['object', 'angle'], flds=[0., 22.95])
osp.spectral_region = WvlSpec([(486.1327, 0.5), (587.5618, 1.0), (656.2725, 0.5)], ref_wl=1)
opm.system_spec.title = "US2019/0265441 Example 2 (Canon RF 50mm F1.2 L USM)"
opm.system_spec.dimensions = 'MM'
opm.radius_mode = True
sm.gaps[0].thi=1e10
sm.add_surface([80.11,9.67,1.804,46.58])
sm.ifcs[sm.cur_surface].profile = EvenPolynomial(r=80.11, cc=0.0,
	coefs=[0.0,-1.44652E-6,-1.02693E-9,1.91678E-12,-3.07794E-15,2.00476E-18,0.0])
sm.ifcs[sm.cur_surface].max_aperture = 20.5
sm.add_surface([-68.243,1.64,1.68893,31.07])
sm.ifcs[sm.cur_surface].max_aperture = 20.5
sm.add_surface([52.862,0.2])
sm.ifcs[sm.cur_surface].max_aperture = 19.145
sm.add_surface([42.184,7.47,2.001,29.13])
sm.ifcs[sm.cur_surface].max_aperture = 19.2
sm.add_surface([2510.58,0.7])
sm.ifcs[sm.cur_surface].max_aperture = 19.2
sm.add_surface([99.979,1.6,1.65412,39.68])
sm.ifcs[sm.cur_surface].max_aperture = 17.6
sm.add_surface([24.508,7.45])
sm.ifcs[sm.cur_surface].max_aperture = 15.76
sm.add_surface([-101.919,1.34,1.66565,35.64])
sm.ifcs[sm.cur_surface].max_aperture = 15.755
sm.add_surface([34.799,5.56,1.95375,32.32])
sm.ifcs[sm.cur_surface].max_aperture = 15.755
sm.add_surface([516.053,2.44])
sm.ifcs[sm.cur_surface].max_aperture = 15.755
sm.add_surface([0.0,2.58])
sm.set_stop()
sm.ifcs[sm.cur_surface].max_aperture = 15.4355
sm.add_surface([-1398.232,10.02,1.497,81.54])
sm.ifcs[sm.cur_surface].max_aperture = 15.95
sm.add_surface([-20.985,1.29,1.738,32.26])
sm.ifcs[sm.cur_surface].max_aperture = 15.95
sm.add_surface([251.143,0.44])
sm.ifcs[sm.cur_surface].max_aperture = 15.95
sm.add_surface([87.566,7.29,1.76385,48.51])
sm.ifcs[sm.cur_surface].max_aperture = 16.45
sm.add_surface([-43.447,1.28,1.66565,35.64])
sm.ifcs[sm.cur_surface].max_aperture = 16.45
sm.add_surface([105.692,1.79])
sm.ifcs[sm.cur_surface].max_aperture = 16.45
sm.add_surface([161.695,7.96,1.883,40.8])
sm.ifcs[sm.cur_surface].profile = EvenPolynomial(r=161.695, cc=0.0,
	coefs=[0.0,-2.17027E-6,4.00496E-9,-1.90948E-11,4.86536E-14,-4.89586E-17,0.0])
sm.ifcs[sm.cur_surface].max_aperture = 16.75
sm.add_surface([-42.423,1.95])
sm.ifcs[sm.cur_surface].max_aperture = 16.75
sm.add_surface([54.474,8.77,1.883,40.8])
sm.ifcs[sm.cur_surface].max_aperture = 18.35
sm.add_surface([-60.531,1.54,1.59551,39.24])
sm.ifcs[sm.cur_surface].max_aperture = 18.35
sm.add_surface([40.56,7.14])
sm.ifcs[sm.cur_surface].max_aperture = 18.05
sm.add_surface([-58.17,1.21,1.673,38.15])
sm.ifcs[sm.cur_surface].max_aperture = 18.05
sm.add_surface([105.985,5.08,1.804,46.58])
sm.ifcs[sm.cur_surface].max_aperture = 18.05
sm.add_surface([-216.191,14.6])
sm.ifcs[sm.cur_surface].profile = EvenPolynomial(r=-216.191, cc=0.0,
	coefs=[0.0,3.50064E-6,-5.9867E-10,1.34319E-11,-2.56798E-14,2.5993E-17,0.0])
sm.ifcs[sm.cur_surface].max_aperture = 18.05
sm.list_surfaces()
sm.list_gaps()
sm.do_apertures = False
opm.update_model()
apply_paraxial_vignetting(opm)
layout_plt = plt.figure(FigureClass=InteractiveLayout, opt_model=opm, do_draw_rays=True, do_paraxial_layout=False,
                        is_dark=isdark).plot()
sm.list_model()
# List the optical specifications
pm.first_order_data()
# List the paraxial model
pm.list_lens()
# Plot the transverse ray aberrations
abr_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='Ray', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot the wavefront aberration
wav_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='OPD', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot spot diagrams
spot_plt = plt.figure(FigureClass=SpotDiagramFigure, opt_model=opm, 
                      scale_type=Fit.User_Scale, user_scale_value=0.1, is_dark=isdark).plot()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# 0 Surface(lbl='Obj', profile=Spherical(c=0.0), interact_mode='dummy')
# 1 Surface(profile=EvenPolynomial(c=0.012482836100362002, cc=0.0, coefs=[0.0, -1.44652e-06, -1.02693e-09, 1.91678e-12, -3.07794e-15, 2.00476e-18, 0.0]), interact_mode='transmit')
# 2 Surface(profile=Spherical(c=-0.014653517576894334), interact_mode='transmit')
# 3 Surface(profile=Spherical(c=0.01891718058340585), interact_mode='transmit')
# 4 Surface(profile=Spherical(c=0.023705670396358812), interact_mode='transmit')
# 5 Surface(profile=Spherical(c=0.00039831433373961394), interact_mode='transmit')
# 6 Surface(profile=Spherical(c=0.01000210044109263), interact_mode='transmit')
# 7 Surface(profile=Spherical(c=0.04080300310102824), interact_mode='transmit')
# 8 Surface(profile=Spherical(c=-0.009811713223245911), interact_mode='transmit')
# 9 Surface(profile=Spherical(c=0.0287364579441938), interact_mode='transmit')
# ...

# %%
# US2019/0265441 Example 2 (Canon RF 50mm F1.2 L USM)
# Obtained via https://www.photonstophotos.net/GeneralTopics/Lenses/OpticalBench/OpticalBenchHub.htm

opm = OpticalModel()
sm  = opm.seq_model
osp = opm.optical_spec
pm = opm.parax_model
osp.pupil = PupilSpec(osp, key=['image', 'f/#'], value=1.25)
osp.field_of_view = FieldSpec(osp, key=['object', 'angle'], flds=[0., 22.95])
osp.spectral_region = WvlSpec([(486.1327, 0.5), (587.5618, 1.0), (656.2725, 0.5)], ref_wl=1)
opm.system_spec.title = "US2019/0265441 Example 2 (Canon RF 50mm F1.2 L USM)"
opm.system_spec.dimensions = 'MM'
opm.radius_mode = True
sm.gaps[0].thi=1e10
sm.add_surface([80.11,9.67,'S-LAH65V','Ohara'])
sm.ifcs[sm.cur_surface].profile = EvenPolynomial(r=80.11, cc=0.0,
	coefs=[0.0,-1.44652E-6,-1.02693E-9,1.91678E-12,-3.07794E-15,2.00476E-18,0.0])
sm.ifcs[sm.cur_surface].max_aperture = 20.5
sm.add_surface([-68.243,1.64,'S-TIM28','Ohara'])
sm.ifcs[sm.cur_surface].max_aperture = 20.5
sm.add_surface([52.862,0.2])
sm.ifcs[sm.cur_surface].max_aperture = 19.145
sm.add_surface([42.184,7.47,'S-LAH99','Ohara'])
sm.ifcs[sm.cur_surface].max_aperture = 19.2
sm.add_surface([2510.58,0.7])
sm.ifcs[sm.cur_surface].max_aperture = 19.2
sm.add_surface([99.979,1.6,'S-NBH 5','Ohara'])
sm.ifcs[sm.cur_surface].max_aperture = 17.6
sm.add_surface([24.508,7.45])
sm.ifcs[sm.cur_surface].max_aperture = 15.76
sm.add_surface([-101.919,1.34,1.66565,35.64])
sm.ifcs[sm.cur_surface].max_aperture = 15.755
sm.add_surface([34.799,5.56,'S-LAH98','Ohara'])
sm.ifcs[sm.cur_surface].max_aperture = 15.755
sm.add_surface([516.053,2.44])
sm.ifcs[sm.cur_surface].max_aperture = 15.755
sm.add_surface([0.0,2.58])
sm.set_stop()
sm.ifcs[sm.cur_surface].max_aperture = 15.4355
sm.add_surface([-1398.232,10.02,'S-FPL51','Ohara'])
sm.ifcs[sm.cur_surface].max_aperture = 15.95
sm.add_surface([-20.985,1.29,'S-NBH53V','Ohara'])
sm.ifcs[sm.cur_surface].max_aperture = 15.95
sm.add_surface([251.143,0.44])
sm.ifcs[sm.cur_surface].max_aperture = 15.95
sm.add_surface([87.566,7.29,'S-LAH96','Ohara'])
sm.ifcs[sm.cur_surface].max_aperture = 16.45
sm.add_surface([-43.447,1.28,1.66565,35.64])
sm.ifcs[sm.cur_surface].max_aperture = 16.45
sm.add_surface([105.692,1.79])
sm.ifcs[sm.cur_surface].max_aperture = 16.45
sm.add_surface([161.695,7.96,'S-LAH58','Ohara'])
sm.ifcs[sm.cur_surface].profile = EvenPolynomial(r=161.695, cc=0.0,
	coefs=[0.0,-2.17027E-6,4.00496E-9,-1.90948E-11,4.86536E-14,-4.89586E-17,0.0])
sm.ifcs[sm.cur_surface].max_aperture = 16.75
sm.add_surface([-42.423,1.95])
sm.ifcs[sm.cur_surface].max_aperture = 16.75
sm.add_surface([54.474,8.77,'S-LAH58','Ohara'])
sm.ifcs[sm.cur_surface].max_aperture = 18.35
sm.add_surface([-60.531,1.54,'S-TIM 8','Ohara'])
sm.ifcs[sm.cur_surface].max_aperture = 18.35
sm.add_surface([40.56,7.14])
sm.ifcs[sm.cur_surface].max_aperture = 18.05
sm.add_surface([-58.17,1.21,'S-NBH52V','Ohara'])
sm.ifcs[sm.cur_surface].max_aperture = 18.05
sm.add_surface([105.985,5.08,'S-LAH65V','Ohara'])
sm.ifcs[sm.cur_surface].max_aperture = 18.05
sm.add_surface([-216.191,14.6])
sm.ifcs[sm.cur_surface].profile = EvenPolynomial(r=-216.191, cc=0.0,
	coefs=[0.0,3.50064E-6,-5.9867E-10,1.34319E-11,-2.56798E-14,2.5993E-17,0.0])
sm.ifcs[sm.cur_surface].max_aperture = 18.05
sm.list_surfaces()
sm.list_gaps()
sm.do_apertures = False
opm.update_model()
apply_paraxial_vignetting(opm)
layout_plt = plt.figure(FigureClass=InteractiveLayout, opt_model=opm, do_draw_rays=True, do_paraxial_layout=False,
                        is_dark=isdark).plot()
sm.list_model()
# List the optical specifications
pm.first_order_data()
# List the paraxial model
pm.list_lens()
# Plot the transverse ray aberrations
abr_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='Ray', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot the wavefront aberration
wav_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='OPD', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot spot diagrams
spot_plt = plt.figure(FigureClass=SpotDiagramFigure, opt_model=opm, 
                      scale_type=Fit.User_Scale, user_scale_value=0.1, is_dark=isdark).plot()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# 0 Surface(lbl='Obj', profile=Spherical(c=0.0), interact_mode='dummy')
# 1 Surface(profile=EvenPolynomial(c=0.012482836100362002, cc=0.0, coefs=[0.0, -1.44652e-06, -1.02693e-09, 1.91678e-12, -3.07794e-15, 2.00476e-18, 0.0]), interact_mode='transmit')
# 2 Surface(profile=Spherical(c=-0.014653517576894334), interact_mode='transmit')
# 3 Surface(profile=Spherical(c=0.01891718058340585), interact_mode='transmit')
# 4 Surface(profile=Spherical(c=0.023705670396358812), interact_mode='transmit')
# 5 Surface(profile=Spherical(c=0.00039831433373961394), interact_mode='transmit')
# 6 Surface(profile=Spherical(c=0.01000210044109263), interact_mode='transmit')
# 7 Surface(profile=Spherical(c=0.04080300310102824), interact_mode='transmit')
# 8 Surface(profile=Spherical(c=-0.009811713223245911), interact_mode='transmit')
# ...
