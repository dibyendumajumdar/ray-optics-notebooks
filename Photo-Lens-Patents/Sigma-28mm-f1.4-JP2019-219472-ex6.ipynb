# %%
# %matplotlib inline
isdark = False
from rayoptics.environment import *
from rayoptics.elem.elements import Element
from rayoptics.raytr.trace import apply_paraxial_vignetting

# JP 2019-219472 Example 6 (Sigma 28mm F1.4 DG HSM A)
# Obtained via https://www.photonstophotos.net/GeneralTopics/Lenses/OpticalBench/OpticalBenchHub.htm

opm = OpticalModel()
sm  = opm.seq_model
osp = opm.optical_spec
pm = opm.parax_model
osp.pupil = PupilSpec(osp, key=['image', 'f/#'], value=1.46)
osp.field_of_view = FieldSpec(osp, key=['object', 'angle'], flds=[0., 37.39])
osp.spectral_region = WvlSpec([(486.1327, 0.5), (587.5618, 1.0), (656.2725, 0.5)], ref_wl=1)
opm.system_spec.title = "JP 2019-219472 Example 6 (Sigma 28mm F1.4 DG HSM A)"
opm.system_spec.dimensions = 'MM'
opm.radius_mode = True
sm.gaps[0].thi=1e10
sm.add_surface([47.3207,1.9,'S-LAH96','Ohara'])
sm.ifcs[sm.cur_surface].max_aperture = 28.99
sm.add_surface([25.137,8.4554])
sm.ifcs[sm.cur_surface].max_aperture = 21.82
sm.add_surface([46.9543,2.4,'M-PCD51','Hoya'])
sm.ifcs[sm.cur_surface].profile = EvenPolynomial(r=46.9543, cc=0.0,
	coefs=[0.0,-5.1231E-6,1.0612E-8,-9.9412E-12,0.0,0.0,0.0,0.0])
sm.ifcs[sm.cur_surface].max_aperture = 23.74
sm.add_surface([23.2091,8.1561])
sm.ifcs[sm.cur_surface].profile = EvenPolynomial(r=23.2091, cc=-1.0,
	coefs=[0.0,-4.8891E-6,3.7734E-9,9.3013E-12,-5.7662E-14,3.3125E-17,0.0,0.0])
sm.ifcs[sm.cur_surface].max_aperture = 23.74
sm.add_surface([618.4976,3.233,'TAFD45','Hoya'])
sm.ifcs[sm.cur_surface].max_aperture = 20.97
sm.add_surface([-139.999,4.0127])
sm.ifcs[sm.cur_surface].max_aperture = 20.97
sm.add_surface([-40.5659,1.7,'FCD100','Hoya'])
sm.ifcs[sm.cur_surface].max_aperture = 20.405
sm.add_surface([94.3906,6.6136,'TAFD35','Hoya'])
sm.ifcs[sm.cur_surface].max_aperture = 21.76
sm.add_surface([-70.5544,2.4296])
sm.ifcs[sm.cur_surface].max_aperture = 21.76
sm.add_surface([-46.9968,1.5,'S-NBH53V','Ohara'])
sm.ifcs[sm.cur_surface].max_aperture = 20.25
sm.add_surface([32.1175,8.6744,'FCD515','Hoya'])
sm.ifcs[sm.cur_surface].max_aperture = 20.87
sm.add_surface([-544.2563,0.25])
sm.ifcs[sm.cur_surface].max_aperture = 20.87
sm.add_surface([60.1374,7.5297,'TAF3D','Hoya'])
sm.ifcs[sm.cur_surface].max_aperture = 22.03
sm.add_surface([-94.6982,7.0149])
sm.ifcs[sm.cur_surface].max_aperture = 22.03
sm.add_surface([69.9167,4.356,'S-LAH96','Ohara'])
sm.ifcs[sm.cur_surface].max_aperture = 21.0
sm.add_surface([-904.2656,0.15])
sm.ifcs[sm.cur_surface].max_aperture = 21.0
sm.add_surface([112.6199,3.6175,'M-TAF101','Hoya'])
sm.ifcs[sm.cur_surface].profile = EvenPolynomial(r=112.6199, cc=0.0,
	coefs=[0.0,-2.6581E-6,-1.9882E-9,-1.8211E-11,5.9593E-14,0.0,0.0,0.0])
sm.ifcs[sm.cur_surface].max_aperture = 20.25
sm.add_surface([-158.1655,0.15])
sm.ifcs[sm.cur_surface].profile = EvenPolynomial(r=-158.1655, cc=0.0,
	coefs=[0.0,1.0964E-6,-4.7729E-9,-3.7791E-12,4.3214E-14,0.0,0.0,0.0])
sm.ifcs[sm.cur_surface].max_aperture = 20.25
sm.add_surface([385.7929,4.1192,'E-FDS1','Hoya'])
sm.ifcs[sm.cur_surface].max_aperture = 18.96
sm.add_surface([-67.3866,1.1,'S-NBH53V','Ohara'])
sm.ifcs[sm.cur_surface].max_aperture = 18.96
sm.add_surface([30.2728,5.694])
sm.ifcs[sm.cur_surface].max_aperture = 15.54
sm.add_surface([0.0,5.1548])
sm.set_stop()
sm.ifcs[sm.cur_surface].max_aperture = 14.1
sm.add_surface([-40.645,7.8692,'FCD1','Hoya'])
sm.ifcs[sm.cur_surface].max_aperture = 14.45
sm.add_surface([-17.6592,1.0,'N-KZFS8','Schott'])
sm.ifcs[sm.cur_surface].max_aperture = 15.97
sm.add_surface([89.6119,4.161,'FCD1','Hoya'])
sm.ifcs[sm.cur_surface].max_aperture = 16.98
sm.add_surface([-102.4644,0.15])
sm.ifcs[sm.cur_surface].max_aperture = 16.98
sm.add_surface([67.2593,8.6087,'FCD515','Hoya'])
sm.ifcs[sm.cur_surface].max_aperture = 17.56
sm.add_surface([-32.5264,0.15])
sm.ifcs[sm.cur_surface].max_aperture = 17.56
sm.add_surface([-74.3568,3.4,'M-TAF101','Hoya'])
sm.ifcs[sm.cur_surface].profile = EvenPolynomial(r=-74.3568, cc=0.0,
	coefs=[0.0,-7.2907E-6,-9.4121E-9,8.7358E-11,-1.2811E-13,0.0,0.0,0.0])
sm.ifcs[sm.cur_surface].max_aperture = 15.89
sm.add_surface([-43.9446,36.5101])
sm.ifcs[sm.cur_surface].profile = EvenPolynomial(r=-43.9446, cc=0.0,
	coefs=[0.0,-3.3343E-7,-6.1575E-9,7.6511E-11,-9.5067E-14,0.0,0.0,0.0])
sm.ifcs[sm.cur_surface].max_aperture = 17.78
sm.add_surface([0.0,1.45,1.52301,58.59])
sm.ifcs[sm.cur_surface].max_aperture = 23.59
sm.add_surface([0.0,1.0])
sm.ifcs[sm.cur_surface].max_aperture = 23.59
sm.list_surfaces()
sm.list_gaps()
sm.do_apertures = False
opm.update_model()
apply_paraxial_vignetting(opm)
layout_plt = plt.figure(FigureClass=InteractiveLayout, opt_model=opm, do_draw_rays=True, do_paraxial_layout=False,
                        is_dark=isdark).plot()
sm.list_model()
# List the optical specifications
pm.first_order_data()
# List the paraxial model
pm.list_lens()
# Plot the transverse ray aberrations
abr_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='Ray', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot the wavefront aberration
wav_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='OPD', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot spot diagrams
spot_plt = plt.figure(FigureClass=SpotDiagramFigure, opt_model=opm, 
                      scale_type=Fit.User_Scale, user_scale_value=0.1, is_dark=isdark).plot()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# 0 Surface(lbl='Obj', profile=Spherical(c=0.0), interact_mode='dummy')
# 1 Surface(profile=Spherical(c=0.021132400830926), interact_mode='transmit')
# 2 Surface(profile=Spherical(c=0.039781994669212714), interact_mode='transmit')
# 3 Surface(profile=EvenPolynomial(c=0.021297303974289892, cc=0.0, coefs=[0.0, -5.1231e-06, 1.0612e-08, -9.9412e-12, 0.0, 0.0, 0.0, 0.0]), interact_mode='transmit')
# 4 Surface(profile=EvenPolynomial(c=0.043086547948864885, cc=-1.0, coefs=[0.0, -4.8891e-06, 3.7734e-09, 9.3013e-12, -5.7662e-14, 3.3125e-17, 0.0, 0.0]), interact_mode='transmit')
# 5 Surface(profile=Spherical(c=0.0016168211485380055), interact_mode='transmit')
# 6 Surface(profile=Spherical(c=-0.007142908163629741), interact_mode='transmit')
# 7 Surface(profile=Spherical(c=-0.02465124649027878), interact_mode='transmit')
# ...
