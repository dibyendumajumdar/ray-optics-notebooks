# %%
# %matplotlib inline
isdark = False
from rayoptics.environment import *
from rayoptics.elem.elements import Element
from rayoptics.raytr.trace import apply_paraxial_vignetting
from rayoptics.raytr.wideangle import *

# US 7,359,125 Example 1 (Nikon AF-S Nikkor 14-24mm f/2.8G ED)
# Obtained via https://www.photonstophotos.net/GeneralTopics/Lenses/OpticalBench/OpticalBenchHub.htm

opm = OpticalModel()
sm  = opm['seq_model']
osp = opm['optical_spec']
fov = osp['fov']
pm = opm['parax_model']
em = opm['ele_model']
pt = opm['part_tree']
ar = opm['analysis_results']
osp['pupil'] = PupilSpec(osp, key=['image', 'f/#'], value=2.88)
#osp.field_of_view = FieldSpec(osp, key=['object', 'angle'], flds=[0., 57.35])
fov = osp['fov'] = FieldSpec(osp, key=['object', 'angle'], value=114.7, flds=[0., 0.7071, 1.0], 
                             is_relative=True, is_wide_angle=True)
osp['wvls'] = WvlSpec([(486.1327, 0.5), (587.5618, 1.0), (656.2725, 0.5)], ref_wl=1)
opm.system_spec.title = "US 7,359,125 Example 1 (Nikon AF-S Nikkor 14-24mm f/2.8G ED)"
opm.system_spec.dimensions = 'MM'
opm.radius_mode = True
sm.gaps[0].thi=1e10
sm.add_surface([60.3937,3.5,'J-LASF015','Hikari'])
sm.ifcs[sm.cur_surface].max_aperture = 41.41
sm.add_surface([32.2703,7.0835])
sm.ifcs[sm.cur_surface].max_aperture = 31.01
sm.add_surface([35.5,4.0,'Q-LAK52S','Hikari'])
sm.ifcs[sm.cur_surface].max_aperture = 29.73
sm.add_surface([19.5117,12.8951])
sm.ifcs[sm.cur_surface].profile = EvenPolynomial(r=19.5117, cc=-0.9087,
	coefs=[0.0,-5.1181E-7,7.1056E-10,-1.9817E-11,1.9226E-14,-6.0945E-18,0.0,0.0])
sm.ifcs[sm.cur_surface].max_aperture = 25.89
sm.add_surface([87.0449,2.5,'J-LAK011','Hikari'])
sm.ifcs[sm.cur_surface].max_aperture = 25.09
sm.add_surface([26.3306,0.3,1.55389,38.09])
sm.ifcs[sm.cur_surface].max_aperture = 19.81
sm.add_surface([30.2448,12.6887])
sm.ifcs[sm.cur_surface].profile = EvenPolynomial(r=30.2448, cc=-7.3795,
	coefs=[0.0,4.2239E-5,-7.8972E-8,2.9788E-10,-5.9331E-13,6.0285E-16,-7.4037E-20,0.0])
sm.ifcs[sm.cur_surface].max_aperture = 19.775
sm.add_surface([-67.993,2.5896,'J-FKH1','Hikari'])
sm.ifcs[sm.cur_surface].max_aperture = 19.775
sm.add_surface([48.0626,2.0])
sm.ifcs[sm.cur_surface].max_aperture = 19.65
sm.add_surface([48.488,5.9634,'J-LASF013','Hikari'])
sm.ifcs[sm.cur_surface].max_aperture = 19.65
sm.add_surface([-181.2948,31.93])
sm.ifcs[sm.cur_surface].max_aperture = 19.65
sm.add_surface([34.6184,1.0,'J-LASF05','Hikari'])
sm.ifcs[sm.cur_surface].max_aperture = 12.07
sm.add_surface([19.4637,5.2931,'J-BAF8','Hikari'])
sm.ifcs[sm.cur_surface].max_aperture = 11.56
sm.add_surface([611.599,5.86])
sm.ifcs[sm.cur_surface].max_aperture = 11.56
sm.add_surface([0.0,1.6689])
sm.set_stop()
sm.ifcs[sm.cur_surface].max_aperture = 9.1645
sm.add_surface([-265.5383,2.6545,'J-BK7','Hikari'])
sm.ifcs[sm.cur_surface].max_aperture = 11.86
sm.add_surface([-47.2569,9.0744])
sm.ifcs[sm.cur_surface].max_aperture = 11.86
sm.add_surface([-27.9322,1.6819,'J-LASF05','Hikari'])
sm.ifcs[sm.cur_surface].max_aperture = 11.76
sm.add_surface([138.6775,0.1])
sm.ifcs[sm.cur_surface].max_aperture = 11.76
sm.add_surface([35.6745,4.4701,'BAFL2','Hoya'])
sm.ifcs[sm.cur_surface].max_aperture = 12.27
sm.add_surface([-71.8719,0.1])
sm.ifcs[sm.cur_surface].max_aperture = 12.27
sm.add_surface([27.2079,1.3817,'J-LASF016','Hikari'])
sm.ifcs[sm.cur_surface].max_aperture = 12.58
sm.add_surface([16.4317,8.491,'J-FKH1','Hikari'])
sm.ifcs[sm.cur_surface].max_aperture = 12.17
sm.add_surface([-53.0,1.721])
sm.ifcs[sm.cur_surface].max_aperture = 12.17
sm.add_surface([1336.7107,1.0,'NBFD13','Hoya'])
sm.ifcs[sm.cur_surface].max_aperture = 12.48
sm.add_surface([20.3824,6.3537,'M-BACD5N','Hoya'])
sm.ifcs[sm.cur_surface].max_aperture = 12.48
sm.add_surface([-60.1135,38.58])
sm.ifcs[sm.cur_surface].profile = EvenPolynomial(r=-60.1135, cc=5.0164,
	coefs=[0.0,1.9855E-5,6.9569E-9,1.5384E-10,-5.8393E-13,0.0,0.0,0.0])
sm.ifcs[sm.cur_surface].max_aperture = 12.48
sm.list_surfaces()
sm.list_gaps()
sm.do_apertures = False
opm.update_model()
cmds.set_vignetting(opm)
opm.update_model()
layout_plt = plt.figure(FigureClass=InteractiveLayout, opt_model=opm, do_draw_rays=True, do_paraxial_layout=False,
                        is_dark=isdark).plot()
sm.list_model()
# List the optical specifications
pm.first_order_data()
# List the paraxial model
pm.list_lens()
# Plot the transverse ray aberrations
abr_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='Ray', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot the wavefront aberration
wav_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='OPD', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot spot diagrams
spot_plt = plt.figure(FigureClass=SpotDiagramFigure, opt_model=opm, 
                      scale_type=Fit.User_Scale, user_scale_value=0.1, is_dark=isdark).plot()
# Out:
# 0 Surface(lbl='Obj', profile=Spherical(c=0.0), interact_mode='dummy')
# 1 Surface(profile=Spherical(c=0.0165580184688138), interact_mode='transmit')
# 2 Surface(profile=Spherical(c=0.030988246158232185), interact_mode='transmit')
# 3 Surface(profile=Spherical(c=0.028169014084507043), interact_mode='transmit')
# 4 Surface(profile=EvenPolynomial(c=0.05125130050175023, cc=-0.9087, coefs=[0.0, -5.1181e-07, 7.1056e-10, -1.9817e-11, 1.9226e-14, -6.0945e-18, 0.0, 0.0]), interact_mode='transmit')
# 5 Surface(profile=Spherical(c=0.011488323842063119), interact_mode='transmit')
# 6 Surface(profile=Spherical(c=0.03797862562949572), interact_mode='transmit')
# 7 Surface(profile=EvenPolynomial(c=0.03306353488864201, cc=-7.3795, coefs=[0.0, 4.2239e-05, -7.8972e-08, 2.9788e-10, -5.9331e-13, 6.0285e-16, -7.4037e-20, 0.0]), interact_mode='transmit')
# 8 Surface(profile=Spherical(c=-0.014707396349624226), interact_mode='transmit')
# 9 Surface(profile=Spherical(c=0.02080619858268175), interact_mode='transmit')
# 10 Surface(profile=Spherical(c=0.02062365946213496), interact_mode='transmit')
# 11 Surface(profile=Spherical(c=-0.005515878006429307), interact_mode='transmit')
# 12 Surface(profile=Spherical(c=0.028886372564878793), interact_mode='transmit')
# 13 Surface(profile=Spherical(c=0.051377692833325626), interact_mode='transmit')
# 14 Surface(profile=Spherical(c=0.001635058265301284), interact_mode='transmit')
# 15 Surface(profile=Spherical(c=0.0), interact_mode='transmit')
# 16 Surface(profile=Spherical(c=-0.0037659350835642165), interact_mode='transmit')
# 17 Surface(profile=Spherical(c=-0.021160930996320115), interact_mode='transmit')
# 18 Surface(profile=Spherical(c=-0.03580097521856495), interact_mode='transmit')
# 19 Surface(profile=Spherical(c=0.0072109751041084524), interact_mode='transmit')
# 20 Surface(profile=Spherical(c=0.028031226786640315), interact_mode='transmit')
# 21 Surface(profile=Spherical(c=-0.013913643579757875), interact_mode='transmit')
# 22 Surface(profile=Spherical(c=0.03675403099834974), interact_mode='transmit')
# 23 Surface(profile=Spherical(c=0.06085797574201087), interact_mode='transmit')
# 24 Surface(profile=Spherical(c=-0.018867924528301886), interact_mode='transmit')
# 25 Surface(profile=Spherical(c=0.0007481050312532098), interact_mode='transmit')
# 26 Surface(profile=Spherical(c=0.04906193578773844), interact_mode='transmit')
# 27 Surface(profile=EvenPolynomial(c=-0.01663519841632911, cc=5.0164, coefs=[0.0, 1.9855e-05, 6.9569e-09, 1.5384e-10, -5.8393e-13, 0.0, 0.0, 0.0]), interact_mode='transmit')
# 28 Surface(lbl='Img', profile=Spherical(c=0.0), interact_mode='dummy')
# 0 Gap(t=10000000000.0, medium=<opticalglass.opticalmedium.Air object at 0x000001DA47C7BE00>)
# 1 Gap(t=3.5, medium=HikariGlass('J-LASF015'))
# 2 Gap(t=7.0835, medium=<opticalglass.opticalmedium.Air object at 0x000001DA4F2E50E0>)
# 3 Gap(t=4.0, medium=HikariGlass('Q-LAK52S'))
# 4 Gap(t=12.8951, medium=<opticalglass.opticalmedium.Air object at 0x000001DA4F2E6F30>)
# 5 Gap(t=2.5, medium=HikariGlass('J-LAK011'))
# 6 Gap(t=0.3, medium=ModelGlass(nd=1.55389, vd=38.09, mat='', cat='user'))
# 7 Gap(t=12.6887, medium=<opticalglass.opticalmedium.Air object at 0x000001DA4F2E5040>)
# 8 Gap(t=2.5896, medium=HikariGlass('J-FKH1'))
# 9 Gap(t=2.0, medium=<opticalglass.opticalmedium.Air object at 0x000001DA4F2E6620>)
# 10 Gap(t=5.9634, medium=HikariGlass('J-LASF013'))
# 11 Gap(t=31.93, medium=<opticalglass.opticalmedium.Air object at 0x000001DA4F2E73E0>)
# 12 Gap(t=1.0, medium=HikariGlass('J-LASF05'))
# 13 Gap(t=5.2931, medium=HikariGlass('J-BAF8'))
# 14 Gap(t=5.86, medium=<opticalglass.opticalmedium.Air object at 0x000001DA4F2E7CA0>)
# 15 Gap(t=1.6689, medium=<opticalglass.opticalmedium.Air object at 0x000001DA4F2E76B0>)
# 16 Gap(t=2.6545, medium=<opticalglass.opticalmedium.Air object at 0x000001DA4F2E4C80>)
# 17 Gap(t=9.0744, medium=<opticalglass.opticalmedium.Air object at 0x000001DA4F2E6DF0>)
# 18 Gap(t=1.6819, medium=HikariGlass('J-LASF05'))
# 19 Gap(t=0.1, medium=<opticalglass.opticalmedium.Air object at 0x000001DA4F2E5590>)
# 20 Gap(t=4.4701, medium=<opticalglass.opticalmedium.Air object at 0x000001DA4F2E5310>)
# 21 Gap(t=0.1, medium=<opticalglass.opticalmedium.Air object at 0x000001DA4F2E7B60>)
# 22 Gap(t=1.3817, medium=HikariGlass('J-LASF016'))
# 23 Gap(t=8.491, medium=HikariGlass('J-FKH1'))
# 24 Gap(t=1.721, medium=<opticalglass.opticalmedium.Air object at 0x000001DA4F2E7A70>)
# 25 Gap(t=1.0, medium=HoyaGlass('NBFD13'))
# 26 Gap(t=6.3537, medium=HoyaGlass('M-BACD5N'))
# 27 Gap(t=38.58, medium=<opticalglass.opticalmedium.Air object at 0x000001DA4F2E7700>)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 92
#      90 sm.list_gaps()
#      91 sm.do_apertures = False
# ---> 92 opm.update_model()
#      93 cmds.set_vignetting(opm)
#      94 opm.update_model()
#
# File C:\Software\miniconda3\envs\ro\Lib\site-packages\rayoptics\optical\opticalmodel.py:336, in OpticalModel.update_model(self, **kwargs)
#     334 self['seq_model'].update_model(**kwargs)
#     335 self['optical_spec'].update_model(**kwargs)
# --> 336 self.update_optical_properties(**kwargs)
#     338 sm = self['seq_model']
#     339 em = self['ele_model']
#
# File C:\Software\miniconda3\envs\ro\Lib\site-packages\rayoptics\optical\opticalmodel.py:352, in OpticalModel.update_optical_properties(self, **kwargs)
#     349 """Compute first order and other optical properties. """
#     351 # OpticalSpec maintains first order and ray aiming for fields
# --> 352 self['optical_spec'].update_optical_properties(**kwargs)
#     353 # Update the ParaxialModel as needed
#     354 self['parax_model'].update_model(**kwargs)
#
# File C:\Software\miniconda3\envs\ro\Lib\site-packages\rayoptics\raytr\opticalspec.py:262, in OpticalSpecs.update_optical_properties(self, **kwargs)
#     260 if self.do_aiming:
#     261     for i, fld in enumerate(self.field_of_view.fields):
# --> 262         fld.aim_info = aim_chief_ray(opm, fld, wvl)
#
# File C:\Software\miniconda3\envs\ro\Lib\site-packages\rayoptics\raytr\trace.py:635, in aim_chief_ray(opt_model, fld, wvl)
#     633 stop = seq_model.stop_surface
#     634 if osp['fov'].is_wide_angle:
# --> 635     aim_info, rr = find_real_enp(opt_model, stop, fld, wvl)
#     637 else:
#     638     aim_info, cr_ray = iterate_ray(opt_model, stop, np.array([0., 0.]),
#     639                                    fld, wvl)
#
# File C:\Software\miniconda3\envs\ro\Lib\site-packages\rayoptics\raytr\wideangle.py:219, in find_real_enp(opm, stop_idx, fld, wvl)
#     214 # print(f"trials: {trial}")
#     215
#     216 # If start and end are equal, then only one ray was successful.
#     217 # Sample z_enp evenly 1 del_z to either side.
#     218 if start_z == end_z:
# --> 219     start_new = start_z - del_z
#     220     end_new = end_z + del_z
#     221     start_z = None
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'float'
