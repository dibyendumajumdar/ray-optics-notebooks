# %%
# %matplotlib inline
isdark = False
from rayoptics.environment import *
from rayoptics.elem.elements import Element
from rayoptics.raytr.trace import apply_paraxial_vignetting

# AI Nikkor 200mm f/2S IF-ED (US 4,176,913 Example 2)
# Obtained via https://www.photonstophotos.net/GeneralTopics/Lenses/OpticalBench/OpticalBenchHub.htm

# Surface[1] = type=S radius=200 thickness=14 diameter = 102.05 nd = 1.50032 vd = 81.9
# Surface[2] = type=S radius=-540 thickness=0.3 diameter = 102.05 nd = 0 vd = 0
# Surface[3] = type=S radius=112.869 thickness=15.5 diameter = 97.28 nd = 1.50032 vd = 81.9
# Surface[4] = type=S radius=-600 thickness=0.65 diameter = 95.61 nd = 0 vd = 0
# Surface[5] = type=S radius=-480 thickness=5 diameter = 95.61 nd = 1.7552 vd = 27.5
# Surface[6] = type=S radius=431.735 thickness=41.201 diameter = 90.51 nd = 0 vd = 0
# Surface[7] = type=S radius=-386 thickness=7.5 diameter = 69.02 nd = 1.79504 vd = 28.4
# Surface[8] = type=S radius=-125 thickness=2.6 diameter = 68.12 nd = 1.4645 vd = 65.8
# Surface[9] = type=S radius=286.185 thickness=21.5 diameter = 68.12 nd = 0 vd = 0
# Surface[10] = type=S radius=-161.2 thickness=3.4 diameter = 55.25 nd = 1.4645 vd = 65.8
# Surface[11] = type=S radius=67.815 thickness=22.912 diameter = 52.63 nd = 0 vd = 0
# Surface[12] = type=S radius=171 thickness=6.5 diameter = 53.71 nd = 1.6935 vd = 53.6
# Surface[13] = type=S radius=-131.975 thickness=2 diameter = 53.71 nd = 0 vd = 0
# Surface[14] = type=S radius=-213 thickness=2 diameter = 52.37 nd = 1.59507 vd = 35.6
# Surface[15] = type=S radius=61 thickness=11 diameter = 50.69 nd = 1.6968 vd = 55.6
# Surface[16] = type=S radius=-193.237 thickness=11.1 diameter = 50.69 nd = 0 vd = 0
# Surface[17] = type=AS radius=0 thickness=10.9 diameter = 40.058 nd = 0 vd = 0
# Surface[18] = type=S radius=-130 thickness=3 diameter = 38.64 nd = 1.4645 vd = 35.74
# Surface[19] = type=S radius=-311.705 thickness=63.59 diameter = 35.74 nd = 0 vd = 0

opm = OpticalModel()
sm  = opm.seq_model
osp = opm.optical_spec
pm = opm.parax_model
osp.pupil = PupilSpec(osp, key=['image', 'f/#'], value=2)
osp.field_of_view = FieldSpec(osp, key=['object', 'angle'], flds=[0., 6.16])
osp.spectral_region = WvlSpec([(486.1327, 0.5), (587.5618, 1.0), (656.2725, 0.5)], ref_wl=1)
opm.system_spec.title = 'AI Nikkor 200mm f/2S IF-ED (US 4,176,913 Example 2)'
opm.system_spec.dimensions = 'MM'
opm.radius_mode = True
sm.gaps[0].thi=1e10
sm.add_surface([200,14,1.50032,81.9])
sm.ifcs[sm.cur_surface].max_aperture = 51.025
sm.add_surface([-540,0.3])
sm.ifcs[sm.cur_surface].max_aperture = 51.025
sm.add_surface([112.869,15.5,1.50032,81.9])
sm.ifcs[sm.cur_surface].max_aperture = 48.64
sm.add_surface([-600,0.65])
sm.ifcs[sm.cur_surface].max_aperture = 47.805
sm.add_surface([-480,5,1.7552,27.5])
sm.ifcs[sm.cur_surface].max_aperture = 47.805
sm.add_surface([431.735,41.201])
sm.ifcs[sm.cur_surface].max_aperture = 45.255
sm.add_surface([-386,7.5,1.79504,28.4])
sm.ifcs[sm.cur_surface].max_aperture = 34.51
sm.add_surface([-125,2.6,1.4645,65.8])
sm.ifcs[sm.cur_surface].max_aperture = 34.06
sm.add_surface([286.185,21.5])
sm.ifcs[sm.cur_surface].max_aperture = 34.06
sm.add_surface([-161.2,3.4,1.4645,65.8])
sm.ifcs[sm.cur_surface].max_aperture = 27.625
sm.add_surface([67.815,22.912])
sm.ifcs[sm.cur_surface].max_aperture = 26.315
sm.add_surface([171,6.5,1.6935,53.6])
sm.ifcs[sm.cur_surface].max_aperture = 26.855
sm.add_surface([-131.975,2])
sm.ifcs[sm.cur_surface].max_aperture = 26.855
sm.add_surface([-213,2,1.59507,35.6])
sm.ifcs[sm.cur_surface].max_aperture = 26.185
sm.add_surface([61,11,1.6968,55.6])
sm.ifcs[sm.cur_surface].max_aperture = 25.345
sm.add_surface([-193.237,11.1])
sm.ifcs[sm.cur_surface].max_aperture = 25.345
sm.add_surface([0,10.9])
sm.set_stop()
sm.ifcs[sm.cur_surface].max_aperture = 20.029
sm.add_surface([-130,3,1.4645,35.74])
sm.ifcs[sm.cur_surface].max_aperture = 19.32
sm.add_surface([-311.705,63.59])
sm.ifcs[sm.cur_surface].max_aperture = 17.87
sm.list_surfaces()
sm.list_gaps()
sm.do_apertures = False
opm.update_model()
apply_paraxial_vignetting(opm)
layout_plt = plt.figure(FigureClass=InteractiveLayout, opt_model=opm, do_draw_rays=True, do_paraxial_layout=False,
                        is_dark=isdark).plot()
sm.list_model()
# List the optical specifications
pm.first_order_data()
# List the paraxial model
pm.list_lens()
# Plot the transverse ray aberrations
abr_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='Ray', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot the wavefront aberration
wav_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='OPD', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot spot diagrams
spot_plt = plt.figure(FigureClass=SpotDiagramFigure, opt_model=opm,
                      scale_type=Fit.User_Scale, user_scale_value=0.1, is_dark=isdark).plot()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# 0 Surface(lbl='Obj', profile=Spherical(c=0.0), interact_mode='dummy')
# 1 Surface(profile=Spherical(c=0.005), interact_mode='transmit')
# 2 Surface(profile=Spherical(c=-0.001851851851851852), interact_mode='transmit')
# 3 Surface(profile=Spherical(c=0.00885982865091389), interact_mode='transmit')
# 4 Surface(profile=Spherical(c=-0.0016666666666666668), interact_mode='transmit')
# 5 Surface(profile=Spherical(c=-0.0020833333333333333), interact_mode='transmit')
# 6 Surface(profile=Spherical(c=0.002316235653815419), interact_mode='transmit')
# 7 Surface(profile=Spherical(c=-0.0025906735751295338), interact_mode='transmit')
# 8 Surface(profile=Spherical(c=-0.008), interact_mode='transmit')
# 9 Surface(profile=Spherical(c=0.0034942432342715377), interact_mode='transmit')
# ...
