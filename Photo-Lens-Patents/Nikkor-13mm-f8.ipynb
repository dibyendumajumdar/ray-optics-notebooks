# %%
# %matplotlib inline
isdark = False
from rayoptics.environment import *
from rayoptics.elem.elements import Element
from rayoptics.raytr.trace import apply_paraxial_vignetting

# US 3,728,011 Example 1
# Obtained via https://www.photonstophotos.net/GeneralTopics/Lenses/OpticalBench/OpticalBenchHub.htm

opm = OpticalModel()
sm  = opm.seq_model
osp = opm.optical_spec
pm = opm.parax_model
osp.pupil = PupilSpec(osp, key=['image', 'f/#'], value=8.0)
osp.field_of_view = FieldSpec(osp, key=['object', 'angle'], value=118/2, flds=[0., 0.7071, 1.0], 
                             is_relative=True, is_wide_angle=True)
osp.spectral_region = WvlSpec([(486.1327, 0.5), (587.5618, 1.0), (656.2725, 0.5)], ref_wl=1)
opm.system_spec.title = "US 3,728,011 Example 1"
opm.system_spec.dimensions = 'MM'
opm.radius_mode = True
sm.gaps[0].thi=1e10
sm.add_surface([57.2,3.9,1.77279,49.5])
sm.ifcs[sm.cur_surface].max_aperture = 53.31
sm.add_surface([43.0,11.9])
sm.ifcs[sm.cur_surface].max_aperture = 42.02
sm.add_surface([51.0,3.0,1.7335,51.0])
sm.ifcs[sm.cur_surface].max_aperture = 42.02
sm.add_surface([37.5,9.3])
sm.ifcs[sm.cur_surface].max_aperture = 35.19
sm.add_surface([48.2,13.5,1.732,53.7])
sm.ifcs[sm.cur_surface].max_aperture = 35.19
sm.add_surface([190.0,0.1])
sm.ifcs[sm.cur_surface].max_aperture = 35.19
sm.add_surface([28.5,1.2,1.7335,51.0])
sm.ifcs[sm.cur_surface].max_aperture = 19.7
sm.add_surface([17.6,3.3])
sm.ifcs[sm.cur_surface].max_aperture = 15.69
sm.add_surface([22.5,1.0,1.732,53.7])
sm.ifcs[sm.cur_surface].max_aperture = 15.69
sm.add_surface([13.2,3.0])
sm.ifcs[sm.cur_surface].max_aperture = 11.995
sm.add_surface([17.6,1.0,1.732,53.7])
sm.ifcs[sm.cur_surface].max_aperture = 11.995
sm.add_surface([12.0,6.5])
sm.ifcs[sm.cur_surface].max_aperture = 10.0
sm.add_surface([0.0,1.2,1.51743,52.3])
sm.ifcs[sm.cur_surface].max_aperture = 12.23
sm.add_surface([0.0,0.5])
sm.ifcs[sm.cur_surface].max_aperture = 12.23
sm.add_surface([350.0,3.0,1.83739,43.5])
sm.ifcs[sm.cur_surface].max_aperture = 9.02
sm.add_surface([12.08,12.3,1.54072,47.2])
sm.ifcs[sm.cur_surface].max_aperture = 7.25
sm.add_surface([-15.8,0.1])
sm.ifcs[sm.cur_surface].max_aperture = 7.25
sm.add_surface([17.0,0.8,1.6968,55.6])
sm.ifcs[sm.cur_surface].max_aperture = 4.96
sm.add_surface([7.45,1.7])
sm.ifcs[sm.cur_surface].max_aperture = 4.1
sm.add_surface([11.9,2.8,1.59507,35.6])
sm.ifcs[sm.cur_surface].max_aperture = 3.65
sm.add_surface([-9.0,0.9,1.60311,60.7])
sm.ifcs[sm.cur_surface].max_aperture = 2.66
sm.add_surface([0.0,0.8])
sm.ifcs[sm.cur_surface].max_aperture = 2.66
sm.add_surface([0.0,0.8])
sm.set_stop()
sm.ifcs[sm.cur_surface].max_aperture = 2.1585
sm.add_surface([0.0,4.1,1.59507,35.6])
sm.ifcs[sm.cur_surface].max_aperture = 2.625
sm.add_surface([-10.5,0.6])
sm.ifcs[sm.cur_surface].max_aperture = 3.745
sm.add_surface([-13.1,1.5,1.86074,23.1])
sm.ifcs[sm.cur_surface].max_aperture = 5.1
sm.add_surface([35.4,0.7])
sm.ifcs[sm.cur_surface].max_aperture = 5.1
sm.add_surface([-41.0,2.2,1.44628,67.2])
sm.ifcs[sm.cur_surface].max_aperture = 5.1
sm.add_surface([-9.6,0.1])
sm.ifcs[sm.cur_surface].max_aperture = 5.34
sm.add_surface([900.0,0.8,1.8663,37.9])
sm.ifcs[sm.cur_surface].max_aperture = 5.34
sm.add_surface([30.7,5.7,1.48749,70.0])
sm.ifcs[sm.cur_surface].max_aperture = 8.63
sm.add_surface([-14.901,37.52])
sm.ifcs[sm.cur_surface].max_aperture = 8.63
sm.list_surfaces()
sm.list_gaps()
sm.do_apertures = False
opm.update_model()
cmds.set_vignetting(opm)
opm.update_model()
layout_plt = plt.figure(FigureClass=InteractiveLayout, opt_model=opm, do_draw_rays=True, do_paraxial_layout=False,
                        is_dark=isdark).plot()
sm.list_model()
# List the optical specifications
pm.first_order_data()
# List the paraxial model
pm.list_lens()
# Plot the transverse ray aberrations
abr_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='Ray', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot the wavefront aberration
wav_plt = plt.figure(FigureClass=RayFanFigure, opt_model=opm,
          data_type='OPD', scale_type=Fit.All_Same, is_dark=isdark).plot()
# Plot spot diagrams
spot_plt = plt.figure(FigureClass=SpotDiagramFigure, opt_model=opm, 
                      scale_type=Fit.User_Scale, user_scale_value=0.1, is_dark=isdark).plot()
# Out:
# 0 Surface(lbl='Obj', profile=Spherical(c=0.0), interact_mode='dummy')
# 1 Surface(profile=Spherical(c=0.01748251748251748), interact_mode='transmit')
# 2 Surface(profile=Spherical(c=0.023255813953488372), interact_mode='transmit')
# 3 Surface(profile=Spherical(c=0.0196078431372549), interact_mode='transmit')
# 4 Surface(profile=Spherical(c=0.02666666666666667), interact_mode='transmit')
# 5 Surface(profile=Spherical(c=0.02074688796680498), interact_mode='transmit')
# 6 Surface(profile=Spherical(c=0.005263157894736842), interact_mode='transmit')
# 7 Surface(profile=Spherical(c=0.03508771929824561), interact_mode='transmit')
# 8 Surface(profile=Spherical(c=0.056818181818181816), interact_mode='transmit')
# 9 Surface(profile=Spherical(c=0.044444444444444446), interact_mode='transmit')
# 10 Surface(profile=Spherical(c=0.07575757575757576), interact_mode='transmit')
# 11 Surface(profile=Spherical(c=0.056818181818181816), interact_mode='transmit')
# 12 Surface(profile=Spherical(c=0.08333333333333333), interact_mode='transmit')
# 13 Surface(profile=Spherical(c=0.0), interact_mode='transmit')
# 14 Surface(profile=Spherical(c=0.0), interact_mode='transmit')
# 15 Surface(profile=Spherical(c=0.002857142857142857), interact_mode='transmit')
# 16 Surface(profile=Spherical(c=0.08278145695364239), interact_mode='transmit')
# 17 Surface(profile=Spherical(c=-0.06329113924050632), interact_mode='transmit')
# 18 Surface(profile=Spherical(c=0.058823529411764705), interact_mode='transmit')
# 19 Surface(profile=Spherical(c=0.1342281879194631), interact_mode='transmit')
# 20 Surface(profile=Spherical(c=0.08403361344537814), interact_mode='transmit')
# 21 Surface(profile=Spherical(c=-0.1111111111111111), interact_mode='transmit')
# 22 Surface(profile=Spherical(c=0.0), interact_mode='transmit')
# 23 Surface(profile=Spherical(c=0.0), interact_mode='transmit')
# 24 Surface(profile=Spherical(c=0.0), interact_mode='transmit')
# 25 Surface(profile=Spherical(c=-0.09523809523809523), interact_mode='transmit')
# 26 Surface(profile=Spherical(c=-0.07633587786259542), interact_mode='transmit')
# 27 Surface(profile=Spherical(c=0.02824858757062147), interact_mode='transmit')
# 28 Surface(profile=Spherical(c=-0.024390243902439025), interact_mode='transmit')
# 29 Surface(profile=Spherical(c=-0.10416666666666667), interact_mode='transmit')
# 30 Surface(profile=Spherical(c=0.0011111111111111111), interact_mode='transmit')
# 31 Surface(profile=Spherical(c=0.03257328990228013), interact_mode='transmit')
# 32 Surface(profile=Spherical(c=-0.06710958996040535), interact_mode='transmit')
# 33 Surface(lbl='Img', profile=Spherical(c=0.0), interact_mode='dummy')
# 0 Gap(t=10000000000.0, medium=<opticalglass.opticalmedium.Air object at 0x000001C61D4AFE00>)
# 1 Gap(t=3.9, medium=ModelGlass(nd=1.77279, vd=49.5, mat='', cat='user'))
# 2 Gap(t=11.9, medium=<opticalglass.opticalmedium.Air object at 0x000001C621F41DB0>)
# 3 Gap(t=3.0, medium=ModelGlass(nd=1.7335, vd=51.0, mat='', cat='user'))
# 4 Gap(t=9.3, medium=<opticalglass.opticalmedium.Air object at 0x000001C621F42120>)
# 5 Gap(t=13.5, medium=ModelGlass(nd=1.732, vd=53.7, mat='', cat='user'))
# 6 Gap(t=0.1, medium=<opticalglass.opticalmedium.Air object at 0x000001C621F41EA0>)
# 7 Gap(t=1.2, medium=ModelGlass(nd=1.7335, vd=51.0, mat='', cat='user'))
# 8 Gap(t=3.3, medium=<opticalglass.opticalmedium.Air object at 0x000001C621F421C0>)
# 9 Gap(t=1.0, medium=ModelGlass(nd=1.732, vd=53.7, mat='', cat='user'))
# 10 Gap(t=3.0, medium=<opticalglass.opticalmedium.Air object at 0x000001C621EDBC50>)
# 11 Gap(t=1.0, medium=ModelGlass(nd=1.732, vd=53.7, mat='', cat='user'))
# 12 Gap(t=6.5, medium=<opticalglass.opticalmedium.Air object at 0x000001C621F41AE0>)
# 13 Gap(t=1.2, medium=ModelGlass(nd=1.51743, vd=52.3, mat='', cat='user'))
# 14 Gap(t=0.5, medium=<opticalglass.opticalmedium.Air object at 0x000001C621F41E00>)
# 15 Gap(t=3.0, medium=ModelGlass(nd=1.83739, vd=43.5, mat='', cat='user'))
# 16 Gap(t=12.3, medium=ModelGlass(nd=1.54072, vd=47.2, mat='', cat='user'))
# 17 Gap(t=0.1, medium=<opticalglass.opticalmedium.Air object at 0x000001C621F41EF0>)
# 18 Gap(t=0.8, medium=ModelGlass(nd=1.6968, vd=55.6, mat='', cat='user'))
# 19 Gap(t=1.7, medium=<opticalglass.opticalmedium.Air object at 0x000001C621F41860>)
# 20 Gap(t=2.8, medium=ModelGlass(nd=1.59507, vd=35.6, mat='', cat='user'))
# 21 Gap(t=0.9, medium=ModelGlass(nd=1.60311, vd=60.7, mat='', cat='user'))
# 22 Gap(t=0.8, medium=<opticalglass.opticalmedium.Air object at 0x000001C621F41950>)
# 23 Gap(t=0.8, medium=<opticalglass.opticalmedium.Air object at 0x000001C621F411D0>)
# 24 Gap(t=4.1, medium=ModelGlass(nd=1.59507, vd=35.6, mat='', cat='user'))
# 25 Gap(t=0.6, medium=<opticalglass.opticalmedium.Air object at 0x000001C621EA1EF0>)
# 26 Gap(t=1.5, medium=ModelGlass(nd=1.86074, vd=23.1, mat='', cat='user'))
# 27 Gap(t=0.7, medium=<opticalglass.opticalmedium.Air object at 0x000001C621EA1F40>)
# 28 Gap(t=2.2, medium=ModelGlass(nd=1.44628, vd=67.2, mat='', cat='user'))
# 29 Gap(t=0.1, medium=<opticalglass.opticalmedium.Air object at 0x000001C621EA1B80>)
# 30 Gap(t=0.8, medium=ModelGlass(nd=1.8663, vd=37.9, mat='', cat='user'))
# 31 Gap(t=5.7, medium=ModelGlass(nd=1.48749, vd=70.0, mat='', cat='user'))
# 32 Gap(t=37.52, medium=<opticalglass.opticalmedium.Air object at 0x000001C621EA16D0>)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 91
#      89 sm.list_gaps()
#      90 sm.do_apertures = False
# ---> 91 opm.update_model()
#      92 cmds.set_vignetting(opm)
#      93 opm.update_model()
#
# File C:\Software\miniconda3\envs\ro\Lib\site-packages\rayoptics\optical\opticalmodel.py:336, in OpticalModel.update_model(self, **kwargs)
#     334 self['seq_model'].update_model(**kwargs)
#     335 self['optical_spec'].update_model(**kwargs)
# --> 336 self.update_optical_properties(**kwargs)
#     338 sm = self['seq_model']
#     339 em = self['ele_model']
#
# File C:\Software\miniconda3\envs\ro\Lib\site-packages\rayoptics\optical\opticalmodel.py:352, in OpticalModel.update_optical_properties(self, **kwargs)
#     349 """Compute first order and other optical properties. """
#     351 # OpticalSpec maintains first order and ray aiming for fields
# --> 352 self['optical_spec'].update_optical_properties(**kwargs)
#     353 # Update the ParaxialModel as needed
#     354 self['parax_model'].update_model(**kwargs)
#
# File C:\Software\miniconda3\envs\ro\Lib\site-packages\rayoptics\raytr\opticalspec.py:262, in OpticalSpecs.update_optical_properties(self, **kwargs)
#     260 if self.do_aiming:
#     261     for i, fld in enumerate(self.field_of_view.fields):
# --> 262         fld.aim_info = aim_chief_ray(opm, fld, wvl)
#
# File C:\Software\miniconda3\envs\ro\Lib\site-packages\rayoptics\raytr\trace.py:635, in aim_chief_ray(opt_model, fld, wvl)
#     633 stop = seq_model.stop_surface
#     634 if osp['fov'].is_wide_angle:
# --> 635     aim_info, rr = find_real_enp(opt_model, stop, fld, wvl)
#     637 else:
#     638     aim_info, cr_ray = iterate_ray(opt_model, stop, np.array([0., 0.]),
#     639                                    fld, wvl)
#
# File C:\Software\miniconda3\envs\ro\Lib\site-packages\rayoptics\raytr\wideangle.py:219, in find_real_enp(opm, stop_idx, fld, wvl)
#     214 # print(f"trials: {trial}")
#     215
#     216 # If start and end are equal, then only one ray was successful.
#     217 # Sample z_enp evenly 1 del_z to either side.
#     218 if start_z == end_z:
# --> 219     start_new = start_z - del_z
#     220     end_new = end_z + del_z
#     221     start_z = None
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'float'
